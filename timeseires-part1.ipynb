# %%
#obs -> models
#1. TS1(sales, leading indicator) -> TS2(stock price)
#2. auto-corelation. 
#3. (unknown TS1) -> TS2  only TS2 obersable.  trend, seasonality, special events. 
#4. predictions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(1)
date_range = pd.date_range(start='1/1/2023', periods=365)

trend = pd.Series(np.linspace(1000, 1100, len(date_range)), index=date_range)

daily_sales = trend + np.random.normal(0, 50, len(date_range))

stock_price = pd.Series(daily_sales.shift(7) + np.random.normal(0, 10, len(date_range)), index=date_range)

data = pd.DataFrame({'daily_sales': daily_sales, 'stock_price': stock_price})

data = data.dropna()

plt.figure(figsize=(10, 6))
plt.plot(data['daily_sales'], label='Daily Sales', color='blue')
plt.plot(data['stock_price'], label='Stock Price', color='red')
plt.title('Daily Sales and Stock Price over Time')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

np.random.seed(1)
n = 1000 
c = 0.6 
trend = 0.01  
std_dev = 3 

time_series = np.zeros(n)
noise = np.random.normal(0, std_dev, n)  

for t in range(1, n):
    time_series[t] = trend * t + c * time_series[t-1] + noise[t]

df = pd.DataFrame({'value': time_series})

df.plot()
plt.show()
